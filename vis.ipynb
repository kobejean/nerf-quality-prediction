# %%
import torch
import numpy as np
features = np.load("outputs/Drums/nqp-tensorf-half-color/2023-10-18_204138/renders/000000-features.npy")

# %%
print(features.shape)
# Out:
# (800, 800, 198)

# %%
print(features[399,399])
print(np.max(np.max(features, axis=0), axis=0))
print(np.min(np.min(features, axis=0), axis=0))
# Out:
# [-3.48300517e-01  1.84606537e-01 -9.07796100e-02  4.24746908e-02
#   4.93379295e-01  2.98910495e-02 -8.53999630e-02  2.97497362e-01
#  -8.93076956e-02 -1.59062333e-02 -3.25338602e-01 -1.65925026e-01
#  -1.85010254e-01 -7.87027478e-02  5.41651882e-02 -5.16791701e-01
#  -3.86449397e-02  6.47030771e-02 -9.16978419e-02 -2.59133130e-01
#   2.56111920e-01  1.85577959e-01 -3.81431103e-01 -3.85276377e-01
#  -1.84729099e-02  7.88927078e-02 -5.67332953e-02  3.99999437e-04
#  -6.79323375e-01 -7.33837306e-01 -7.22752512e-01  1.05716512e-01
#   8.82665992e-01 -7.36827791e-01 -4.47458327e-01  3.90843451e-01
#   2.50048131e-01  3.63913506e-01 -1.47170871e-01 -2.62282282e-01
#   1.68098226e-01  3.37456353e-02 -4.72448617e-01 -4.59532201e-01
#   8.00398231e-01  3.91242206e-02 -3.78310174e-01 -1.50060982e-01
#  -8.89389813e-02 -2.56718285e-02 -7.31911063e-01  2.00774014e-01
#  -6.50874794e-01  8.93503278e-02 -7.28699625e-01  1.02350704e-01
# ...
